# %%
'''
A Recurrent Neural Network (LSTM) implementation example using TensorFlow library.
This example is using the MNIST database of handwritten digits (http://yann.lecun.com/exdb/mnist/)
Long Short Term Memory paper: http://deeplearning.cs.cmu.edu/pdfs/Hochreiter97_lstm.pdf
Author: Aymeric Damien
Project: https://github.com/aymericdamien/TensorFlow-Examples/
https://github.com/aymericdamien/TensorFlow-Examples/blob/master/examples/3_NeuralNetworks/recurrent_network.py
'''

from __future__ import print_function

import tensorflow as tf
from tensorflow.contrib import rnn

# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/", one_hot=True)

'''
To classify images using a recurrent neural network, we consider every image
row as a sequence of pixels. Because MNIST image shape is 28*28px, we will then
handle 28 sequences of 28 steps for every sample.
'''

# Parameters
learning_rate = 0.001
training_iters = 100000
batch_size = 128
display_step = 10

# Network Parameters
n_input = 28 # MNIST data input (img shape: 28*28)
n_steps = 28 # timesteps
n_hidden = 128 # hidden layer num of features
n_classes = 10 # MNIST total classes (0-9 digits)

# tf Graph input
x = tf.placeholder("float", [None, n_steps, n_input])
y = tf.placeholder("float", [None, n_classes])

# Define weights
weights = {
    'out': tf.Variable(tf.random_normal([n_hidden, n_classes]))
}
biases = {
    'out': tf.Variable(tf.random_normal([n_classes]))
}


def RNN(x, weights, biases):

    # Prepare data shape to match `rnn` function requirements
    # Current data input shape: (batch_size, n_steps, n_input)
    # Required shape: 'n_steps' tensors list of shape (batch_size, n_input)

    # Unstack to get a list of 'n_steps' tensors of shape (batch_size, n_input)
    x = tf.unstack(x, n_steps, 1)

    # Define a lstm cell with tensorflow
    lstm_cell = rnn.BasicLSTMCell(n_hidden, forget_bias=1.0)

    # Get lstm cell output
    outputs, states = rnn.static_rnn(lstm_cell, x, dtype=tf.float32)

    # Linear activation, using rnn inner loop last output
    return tf.matmul(outputs[-1], weights['out']) + biases['out']

pred = RNN(x, weights, biases)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.global_variables_initializer()

# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Reshape data to get 28 seq of 28 elements
        batch_x = batch_x.reshape((batch_size, n_steps, n_input))
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y})
        if step % display_step == 0:
            # Calculate batch accuracy
            acc = sess.run(accuracy, feed_dict={x: batch_x, y: batch_y})
            # Calculate batch loss
            loss = sess.run(cost, feed_dict={x: batch_x, y: batch_y})
            print("Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc))
        step += 1
    print("Optimization Finished!")

    # Calculate accuracy for 128 mnist test images
    test_len = 128
    test_data = mnist.test.images[:test_len].reshape((-1, n_steps, n_input))
    test_label = mnist.test.labels[:test_len]
    print("Testing Accuracy:", \
        sess.run(accuracy, feed_dict={x: test_data, y: test_label}))
# Out:
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# Iter 1280, Minibatch Loss= 1.745790, Training Accuracy= 0.35938
# Iter 2560, Minibatch Loss= 1.603262, Training Accuracy= 0.42969
# Iter 3840, Minibatch Loss= 1.090008, Training Accuracy= 0.64062
# Iter 5120, Minibatch Loss= 1.066502, Training Accuracy= 0.70312
# Iter 6400, Minibatch Loss= 0.890744, Training Accuracy= 0.67969
# Iter 7680, Minibatch Loss= 0.689881, Training Accuracy= 0.78125
# Iter 8960, Minibatch Loss= 0.709139, Training Accuracy= 0.75781
# Iter 10240, Minibatch Loss= 0.617456, Training Accuracy= 0.80469
# Iter 11520, Minibatch Loss= 0.567393, Training Accuracy= 0.82031
# Iter 12800, Minibatch Loss= 0.519836, Training Accuracy= 0.82812
# Iter 14080, Minibatch Loss= 0.402689, Training Accuracy= 0.83594
# Iter 15360, Minibatch Loss= 0.395332, Training Accuracy= 0.89062
# Iter 16640, Minibatch Loss= 0.306397, Training Accuracy= 0.89844
# Iter 17920, Minibatch Loss= 0.430328, Training Accuracy= 0.82812
# Iter 19200, Minibatch Loss= 0.313027, Training Accuracy= 0.91406
# Iter 20480, Minibatch Loss= 0.369366, Training Accuracy= 0.92188
# Iter 21760, Minibatch Loss= 0.260315, Training Accuracy= 0.89062
# Iter 23040, Minibatch Loss= 0.405075, Training Accuracy= 0.85938
# Iter 24320, Minibatch Loss= 0.291806, Training Accuracy= 0.91406
# Iter 25600, Minibatch Loss= 0.207699, Training Accuracy= 0.92969
# Iter 26880, Minibatch Loss= 0.325765, Training Accuracy= 0.89062
# Iter 28160, Minibatch Loss= 0.164918, Training Accuracy= 0.96875
# Iter 29440, Minibatch Loss= 0.250056, Training Accuracy= 0.92188
# Iter 30720, Minibatch Loss= 0.322864, Training Accuracy= 0.86719
# Iter 32000, Minibatch Loss= 0.276597, Training Accuracy= 0.90625
# Iter 33280, Minibatch Loss= 0.147362, Training Accuracy= 0.95312
# Iter 34560, Minibatch Loss= 0.352176, Training Accuracy= 0.89062
# Iter 35840, Minibatch Loss= 0.132859, Training Accuracy= 0.93750
# Iter 37120, Minibatch Loss= 0.212333, Training Accuracy= 0.92188
# Iter 38400, Minibatch Loss= 0.191636, Training Accuracy= 0.92969
# Iter 39680, Minibatch Loss= 0.175428, Training Accuracy= 0.96094
# Iter 40960, Minibatch Loss= 0.155913, Training Accuracy= 0.92969
# Iter 42240, Minibatch Loss= 0.385899, Training Accuracy= 0.89062
# Iter 43520, Minibatch Loss= 0.280639, Training Accuracy= 0.94531
# Iter 44800, Minibatch Loss= 0.255013, Training Accuracy= 0.92188
# Iter 46080, Minibatch Loss= 0.283370, Training Accuracy= 0.91406
# Iter 47360, Minibatch Loss= 0.166261, Training Accuracy= 0.94531
# Iter 48640, Minibatch Loss= 0.148699, Training Accuracy= 0.96094
# Iter 49920, Minibatch Loss= 0.127192, Training Accuracy= 0.96094
# Iter 51200, Minibatch Loss= 0.185019, Training Accuracy= 0.94531
# Iter 52480, Minibatch Loss= 0.210021, Training Accuracy= 0.92969
# Iter 53760, Minibatch Loss= 0.131477, Training Accuracy= 0.95312
# Iter 55040, Minibatch Loss= 0.131838, Training Accuracy= 0.95312
# Iter 56320, Minibatch Loss= 0.180109, Training Accuracy= 0.94531
# Iter 57600, Minibatch Loss= 0.076345, Training Accuracy= 0.96875
# Iter 58880, Minibatch Loss= 0.143947, Training Accuracy= 0.97656
# Iter 60160, Minibatch Loss= 0.111422, Training Accuracy= 0.95312
# Iter 61440, Minibatch Loss= 0.110378, Training Accuracy= 0.95312
# Iter 62720, Minibatch Loss= 0.143672, Training Accuracy= 0.94531
# Iter 64000, Minibatch Loss= 0.132795, Training Accuracy= 0.96094
# Iter 65280, Minibatch Loss= 0.118544, Training Accuracy= 0.95312
# Iter 66560, Minibatch Loss= 0.118283, Training Accuracy= 0.95312
# Iter 67840, Minibatch Loss= 0.106455, Training Accuracy= 0.94531
# Iter 69120, Minibatch Loss= 0.197478, Training Accuracy= 0.94531
# Iter 70400, Minibatch Loss= 0.139993, Training Accuracy= 0.96094
# Iter 71680, Minibatch Loss= 0.169458, Training Accuracy= 0.94531
# Iter 72960, Minibatch Loss= 0.093524, Training Accuracy= 0.97656
# Iter 74240, Minibatch Loss= 0.075072, Training Accuracy= 0.96094
# Iter 75520, Minibatch Loss= 0.128098, Training Accuracy= 0.96875
# Iter 76800, Minibatch Loss= 0.144724, Training Accuracy= 0.93750
# Iter 78080, Minibatch Loss= 0.112854, Training Accuracy= 0.96875
# Iter 79360, Minibatch Loss= 0.095876, Training Accuracy= 0.96094
# Iter 80640, Minibatch Loss= 0.154831, Training Accuracy= 0.94531
# Iter 81920, Minibatch Loss= 0.178807, Training Accuracy= 0.96875
# Iter 83200, Minibatch Loss= 0.123476, Training Accuracy= 0.96094
# Iter 84480, Minibatch Loss= 0.172775, Training Accuracy= 0.93750
# Iter 85760, Minibatch Loss= 0.100863, Training Accuracy= 0.98438
# Iter 87040, Minibatch Loss= 0.145551, Training Accuracy= 0.96094
# Iter 88320, Minibatch Loss= 0.078527, Training Accuracy= 0.96875
# Iter 89600, Minibatch Loss= 0.166623, Training Accuracy= 0.95312
# Iter 90880, Minibatch Loss= 0.192950, Training Accuracy= 0.92188
# Iter 92160, Minibatch Loss= 0.082730, Training Accuracy= 0.96875
# Iter 93440, Minibatch Loss= 0.087689, Training Accuracy= 0.96875
# Iter 94720, Minibatch Loss= 0.102151, Training Accuracy= 0.96875
# Iter 96000, Minibatch Loss= 0.114870, Training Accuracy= 0.96094
# Iter 97280, Minibatch Loss= 0.048774, Training Accuracy= 0.99219
# Iter 98560, Minibatch Loss= 0.123185, Training Accuracy= 0.97656
# Iter 99840, Minibatch Loss= 0.109987, Training Accuracy= 0.96875
# Optimization Finished!
# Testing Accuracy: 0.96875
